# %% [markdown]
# ## Installing the Pandas Library
#
# The `pip install pandas` command is used to install the **Pandas** library in Python. Pandas is one of the most popular libraries for data manipulation, data analysis, and working with structured datasets.
#
# In Google Colab, Pandas is usually pre-installed. However, this command can be used to install or update the library if needed.
#
# **Syntax:**
# ```python
# pip install pandas
# ```
#
# **Purpose:**
# - To install the Pandas library.
# - To enable data analysis and manipulation.
# - To work with DataFrames and Series.
# - To read and write data from files such as CSV, Excel, and JSON.
# - To perform data cleaning, filtering, and statistical analysis.
#
# **Note:**
# In Google Colab, you can also use:
#
# ```python
# %pip install pandas
# ```
#
# The `%pip` command is recommended in Colab because it installs the package directly in the current notebook environment.

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Importing Pandas
#
# `import pandas as pd` imports the **Pandas** library and assigns it the alias **pd**. Pandas is a powerful Python library used for data analysis and manipulation. It helps in reading, organizing, cleaning, filtering, and analyzing datasets efficiently.

# %%
import pandas as pd

# %% [markdown]
# ## Reading Excel File
#
# `df = pd.read_excel('Amazon_Data.xlsx')` reads the Excel file **Amazon_Data.xlsx** and stores the data in a Pandas DataFrame named **df**. It is used for analyzing and manipulating the dataset in Python.

# %%
df = pd.read_excel('Amazon_Data.xlsx')

# %% [markdown]
# ## Display First Rows
#
# `df.head()` displays the first 5 rows of the DataFrame. It is used to quickly view the structure and sample data of the dataset.

# %%
df.head()
# Out:
#   Product Category                                Product Description  \
# 0     Audio Video   Upgraded, Anker Soundcore Bluetooth Speaker wi...
# 1     Audio Video   Twelve South AirFly Pro Bluetooth Wireless Aud...
# 2     Audio Video   iOttie Easy One Touch 5 Dashboard & Windshield...
# 3     Audio Video   INIU Wireless Charger, 15W Fast Wireless Charg...
# 4     Audio Video   JBL Flip 4 Waterproof Portable Bluetooth Speak...
#
#    Price(Dollar)  Number of  reviews             Shipment Order Date
# 0             27               82773  Ships to Bangladesh 2019-01-03
# 1             54                5121  Ships to Bangladesh 2019-01-04
# 2             24              126957  Ships to Bangladesh 2019-01-04
# 3             15               18837  Ships to Bangladesh 2019-01-04
# 4             78               13141  Ships to Bangladesh 2019-01-05

# %% [markdown]
# ## Display Last Rows
#
# `df.tail()` displays the last 5 rows of the DataFrame. It helps to quickly check the ending records of the dataset.

# %%
df.tail()
# Out:
#       Product Category                                Product Description  \
# 89077             Toys  Papo - Hand-Painted - Figurine - Marine Life -...
# 89078             Toys                       Green Toys Farm Playset. CB2
# 89079             Toys  Teenage Mutant Ninja Turtles 5" Sewer Shredder...
# 89080             Toys  Schleich Wild Life, Wild Animal Toys for Kids,...
# 89081             Toys  Schleich bayala, 5-Piece Starter Set with Fair...
#
#        Price(Dollar)  Number of  reviews             Shipment Order Date
# 89077             11                1094  Ships to Bangladesh 2022-04-30
# 89078             26                  78  Ships to Bangladesh 2022-04-30
# 89079             10                  78  Ships to Bangladesh 2022-04-30
# 89080             42                  78  Ships to Bangladesh 2022-04-30
# 89081             34                  78  Ships to Bangladesh 2022-04-30

# %% [markdown]
# ## Statistical Summary
#
# `df.describe()` provides a statistical summary of numerical columns, including count, mean, standard deviation, minimum, and maximum values.

# %%
df.describe()
# Out:
#        Price(Dollar)  Number of  reviews                  Order Date
# count   89082.000000        89082.000000                       89082
# mean       94.527604          657.150592  2021-04-14 08:41:09.347343
# min         0.000000            1.000000         2019-01-03 00:00:00
# 25%        24.000000            8.000000         2020-04-30 00:00:00
# 50%        46.000000           44.000000         2021-06-05 00:00:00
# 75%        86.000000          230.000000         2022-04-16 00:00:00
# max     16775.000000       406442.000000         2022-12-31 00:00:00
# std       280.455093         4973.036959                         NaN

# %% [markdown]
# ## Dataset Shape
#
# `df.shape` returns the number of rows and columns in the DataFrame. It helps to understand the size of the dataset.

# %%
df.shape
# Out:
# (89082, 6)

# %% [markdown]
# ## Dataset Information
#
# `df.info()` provides a concise summary of the DataFrame, including column names, data types, and non-null values.

# %%
df.info
# Out:
# <bound method DataFrame.info of       Product Category                                Product Description  \
# 0         Audio Video   Upgraded, Anker Soundcore Bluetooth Speaker wi...
# 1         Audio Video   Twelve South AirFly Pro Bluetooth Wireless Aud...
# 2         Audio Video   iOttie Easy One Touch 5 Dashboard & Windshield...
# 3         Audio Video   INIU Wireless Charger, 15W Fast Wireless Charg...
# 4         Audio Video   JBL Flip 4 Waterproof Portable Bluetooth Speak...
# ...                ...                                                ...
# 89077             Toys  Papo - Hand-Painted - Figurine - Marine Life -...
# 89078             Toys                       Green Toys Farm Playset. CB2
# 89079             Toys  Teenage Mutant Ninja Turtles 5" Sewer Shredder...
# 89080             Toys  Schleich Wild Life, Wild Animal Toys for Kids,...
# 89081             Toys  Schleich bayala, 5-Piece Starter Set with Fair...
#
# ...

# %% [markdown]
# ## Data Types
#
# `df.dtypes` shows the data type of each column in the DataFrame. It helps to understand the type of data stored in the dataset.

# %%
df.dtypes
# Out:
# Product Category                  str
# Product Description               str
# Price(Dollar)                   int64
# Number of  reviews              int64
# Shipment                          str
# Order Date             datetime64[us]
# dtype: object

# %% [markdown]
# ## Selecting Object Columns
#
# `df.dtypes == 'object'` checks which columns have the object data type. It is mainly used to identify categorical or text-based columns in the dataset.

# %%
df.dtypes=='obeject'
# Out:
# Product Category       False
# Product Description    False
# Price(Dollar)          False
# Number of  reviews     False
# Shipment               False
# Order Date             False
# dtype: bool

# %% [markdown]
# ## Checking Missing Values
#
# `df.isnull().sum()` calculates the total number of missing (null) values in each column of the DataFrame. It helps in identifying incomplete data.

# %%
df.isnull().sum()
# Out:
# Product Category       0
# Product Description    0
# Price(Dollar)          0
# Number of  reviews     0
# Shipment               0
# Order Date             0
# dtype: int64

# %% [markdown]
# ## Complete Statistical Summary
#
# `df.describe(include='all')` provides a detailed summary of all columns, including both numerical and categorical data.

# %%
df.describe(include='all')
# Out:
#        Product Category                                Product Description  \
# count             89082                                              89082
# unique                8                                              67942
# top           Men Shoes  KODAK Step Slim Instant Mobile Color Photo Pri...
# freq              23228                                                429
# mean                NaN                                                NaN
# min                 NaN                                                NaN
# 25%                 NaN                                                NaN
# 50%                 NaN                                                NaN
# 75%                 NaN                                                NaN
# max                 NaN                                                NaN
# std                 NaN                                                NaN
#
#         Price(Dollar)  Number of  reviews             Shipment  \
# ...

# %% [markdown]
# ## Missing Values Check
#
# `df.isnull().sum()` counts the number of missing values in each column of the DataFrame. It helps identify incomplete or null data.

# %%
df.isnull().sum()
# Out:
# Product Category       0
# Product Description    0
# Price(Dollar)          0
# Number of  reviews     0
# Shipment               0
# Order Date             0
# dtype: int64

# %% [markdown]
# ## Total Missing Values
#
# `df.isnull().sum().sum()` calculates the total number of missing values present in the entire DataFrame.

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Duplicate Values Check
#
# `df.duplicated().sum()` counts the total number of duplicate rows present in the DataFrame. It helps identify repeated records in the dataset.

# %%
df.duplicated().sum()
# Out:
# np.int64(135)

# %% [markdown]
# ## Unique Values Count
#
# `df.nunique()` returns the number of unique values in each column of the DataFrame. It helps understand the variety of data in each feature.

# %%
df.nunique()
# Out:
# Product Category           8
# Product Description    67942
# Price(Dollar)           1332
# Number of  reviews      5102
# Shipment                  14
# Order Date              1243
# dtype: int64

# %% [markdown]
# ## Unique Categories
#
# `df['Product Category'].unique()` displays all unique values present in the **Product Category** column. It helps identify different categories in the dataset.

# %%
df['Product Category'].unique()
# Out:
# <StringArray>
# [        'Audio Video ',               'Camera',      'Car Accessories',
#                'Laptop',          'Men Clothes',            'Men Shoes',
#  'Mobile & Accessories',                 'Toys']
# Length: 8, dtype: str

# %% [markdown]
# ## Unique Product Descriptions
#
# `df['Product Description'].unique()` displays all unique values present in the **Product Description** column. It helps identify different product descriptions in the dataset.

# %%
df['Product Description'].unique()
# Out:
# <StringArray>
# [                                                   'Upgraded, Anker Soundcore Bluetooth Speaker with IPX5 Waterproof, Stereo Sound, 24H Playtime, Portable Wireless Speaker for iPhone, Samsung and More',
#  'Twelve South AirFly Pro Bluetooth Wireless Audio Transmitter/ Receiver for up to 2 AirPods /Wireless Headphones; Use with any 3.5 mm Audio Jack on Airplanes, Gym Equipment, TVs, iPad/Tablets and Auto',
#  'iOttie Easy One Touch 5 Dashboard & Windshield Universal Car Mount Phone Holder Desk Stand with Suction Cup Base and Telescopic Arm for iPhone, Samsung, Google, Huawei, Nokia, other Smartphones Black',
#    'INIU Wireless Charger, 15W Fast Wireless Charging Station with Sleep-Friendly Adaptive Light Compatible with iPhone 14 13 12 Pro XR XS 8 Plus Samsung Galaxy S23 S22 S21 S20 Note 20 10 Google LG etc',
# ...

# %% [markdown]
# ## Unique Price Values
#
# `df['Price(Dollar)'].unique()` displays all unique values present in the **Price(Dollar)** column. It helps identify different price values available in the dataset.

# %%
df['Price(Dollar)'].unique()
# Out:
# array([ 27,  54,  24, ..., 702, 529, 543], shape=(1332,))

# %% [markdown]
# ## Unique Review Counts
#
# `df['Number of reviews'].unique()` displays all unique values present in the **Number of reviews** column. It helps analyze different review counts in the dataset.

# %%
df['Number of  reviews'].unique()
# Out:
# array([ 82773,   5121, 126957, ...,   1845,   3221,   5507], shape=(5102,))

# %% [markdown]
# ## Unique Shipment Values
#
# `df['Shipment'].unique()` displays all unique values present in the **Shipment** column. It helps identify different shipment methods or categories in the dataset.

# %%
df['Shipment'].unique()
# Out:
# <StringArray>
# [             'Ships to Bangladesh',                             '& Up',
#  'Get it Fri, Jun 23 - Wed, Jun 28', 'Get it Fri, Jun 30 - Mon, Jul 17',
#  'Get it Mon, Jun 26 - Thu, Jun 29', 'Get it Wed, Jun 28 - Thu, Jul 13',
#   'Get it Thu, Jun 22 - Mon, Jul 3',  'Get it Mon, Jul 3 - Wed, Jul 19',
#   'Get it Thu, Jun 22 - Wed, Jul 5', 'Get it Tue, Jun 20 - Tue, Jun 27',
#   'Get it Mon, Jul 3 - Tue, Jul 25', 'Get it Tue, Jun 27 - Mon, Jul 10',
#   'Get it Thu, Jul 13 - Thu, Aug 3', 'Get it Thu, Jun 29 - Fri, Jul 14']
# Length: 14, dtype: str

# %% [markdown]
# ## Unique Order Dates
#
# `df['Order Date'].unique()` displays all unique values present in the **Order Date** column. It helps identify different dates available in the dataset.

# %%
df['Order Date'].unique()
# Out:
# <DatetimeArray>
# ['2019-01-03 00:00:00', '2019-01-04 00:00:00', '2019-01-05 00:00:00',
#  '2019-01-06 00:00:00', '2019-01-07 00:00:00', '2019-01-09 00:00:00',
#  '2019-01-10 00:00:00', '2019-01-11 00:00:00', '2019-01-13 00:00:00',
#  '2019-01-14 00:00:00',
#  ...
#  '2022-12-22 00:00:00', '2022-12-23 00:00:00', '2022-12-24 00:00:00',
#  '2022-12-25 00:00:00', '2022-12-26 00:00:00', '2022-12-27 00:00:00',
#  '2022-12-28 00:00:00', '2022-12-29 00:00:00', '2022-12-30 00:00:00',
#  '2022-12-31 00:00:00']
# Length: 1243, dtype: datetime64[us]

# %% [markdown]
# ## Category Frequency Count
#
# `df['Product Category'].value_counts()` counts the number of occurrences of each category in the **Product Category** column. It helps analyze the distribution of product categories.

# %%
df['Product Category'].value_counts()
# Out:
# Product Category
# Men Shoes               23228
# Men Clothes             22946
# Camera                  11726
# Toys                    11403
# Car Accessories          9571
# Mobile & Accessories     6932
# Audio Video              2191
# Laptop                   1085
# Name: count, dtype: int64

# %% [markdown]
# ## Product Description Frequency
#
# `df['Product Description'].value_counts()` counts the occurrences of each unique product description. It helps analyze the distribution of product descriptions in the dataset.

# %%
df['Product Description'].value_counts()
# Out:
# Product Description
# KODAK Step Slim Instant Mobile Color Photo Printer – Wirelessly Print 2x3” Photos on Zink Paper with iOS & Android Devices, White                                                                 429
# Canal Toys Photo Creator Instant Print Camera – Photo, Selfie and Video – Thermal Paper for 250 Photos – LCD Screen. 8+                                                                           415
# Atomos Ninja V 5-Inch 4K Photo and Video Portable Monitor | 1920 x 1080 Touchscreen Display Video Monitors with HDMI 2.0 in/Out | SmallRig Camera Hot Shoe Mount, Battery & Charger Bundle Set    411
# Storelli Jumper Socks by Floky, Biomechanical Socks for Basketball and Volleyball, Improve Performance, Protect Against Injuries, Speed up Recovery                                               402
# ...

# %% [markdown]
# ## Price Frequency Count
#
# `df['Price(Dollar)'].value_counts()` counts the number of occurrences of each unique price value in the **Price(Dollar)** column. It helps analyze the distribution of product prices.

# %%
df['Price(Dollar)'].value_counts()
# Out:
# Price(Dollar)
# 49     2810
# 24     2301
# 29     2072
# 19     1986
# 39     1674
#        ...
# 755       1
# 612       1
# 702       1
# 529       1
# 543       1
# Name: count, Length: 1332, dtype: int64

# %% [markdown]
# ## Review Count Frequency
#
# `df['Number of reviews'].value_counts()` counts the occurrences of each unique review count in the **Number of reviews** column. It helps analyze the distribution of customer reviews.

# %%
df['Number of  reviews'].value_counts()
# Out:
# Number of  reviews
# 1       5572
# 2       4435
# 4       3196
# 3       3145
# 28      2963
#         ...
# 5391       1
# 5680       1
# 1845       1
# 3221       1
# 5507       1
# Name: count, Length: 5102, dtype: int64

# %% [markdown]
# ## Shipment Frequency Count
#
# `df['Shipment'].value_counts()` counts the occurrences of each unique shipment value in the **Shipment** column. It helps analyze the distribution of shipment methods.

# %%
df['Shipment'].value_counts()
# Out:
# Shipment
# Ships to Bangladesh                 88126
# & Up                                  928
# Get it Thu, Jun 22 - Wed, Jul 5         8
# Get it Tue, Jun 20 - Tue, Jun 27        3
# Get it Mon, Jul 3 - Tue, Jul 25         3
# Get it Tue, Jun 27 - Mon, Jul 10        3
# Get it Fri, Jun 23 - Wed, Jun 28        2
# Get it Fri, Jun 30 - Mon, Jul 17        2
# Get it Mon, Jul 3 - Wed, Jul 19         2
# Get it Mon, Jun 26 - Thu, Jun 29        1
# Get it Wed, Jun 28 - Thu, Jul 13        1
# Get it Thu, Jun 22 - Mon, Jul 3         1
# Get it Thu, Jul 13 - Thu, Aug 3         1
# Get it Thu, Jun 29 - Fri, Jul 14        1
# Name: count, dtype: int64

# %% [markdown]
# ## Order Date Frequency Count
#
# `df['Order Date'].value_counts()` counts the occurrences of each unique date in the **Order Date** column. It helps analyze the frequency of orders on different dates.

# %%
df['Order Date'].value_counts()
# Out:
# Order Date
# 2021-09-05    342
# 2021-11-10    315
# 2022-12-02    296
# 2022-09-02    288
# 2022-12-09    280
#              ...
# 2022-10-04      8
# 2022-10-29      8
# 2022-11-22      8
# 2022-12-06      8
# 2022-12-31      1
# Name: count, Length: 1243, dtype: int64

# %% [markdown]
# ## Correlation Analysis
#
# `df.corr(numeric_only=True)` calculates the correlation between numerical columns in the DataFrame. It helps identify relationships between different numerical features.

# %%
df.corr(numeric_only=True)
# Out:
#                     Price(Dollar)  Number of  reviews
# Price(Dollar)            1.000000           -0.012799
# Number of  reviews      -0.012799            1.000000

# %% [markdown]
# ## Dataset Dimensions
#
# This code prints the total number of rows and columns in the DataFrame using `df.shape`. It helps understand the size of the dataset.

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Rows: 89082
# Columns: 6

# %% [markdown]
# ## Memory Usage Analysis
#
# `df.memory_usage(deep=True)` calculates the memory consumed by each column in the DataFrame. It helps understand the dataset's memory requirements.

# %%
df.memory_usage(deep=True)
# Out:
# Index                       132
# Product Category        5257451
# Product Description    12144048
# Price(Dollar)            712656
# Number of  reviews       712656
# Shipment                6044005
# Order Date               712656
# dtype: int64

# %% [markdown]
# ## Random Data Sampling
#
# `df.sample(5)` randomly selects and displays 5 rows from the DataFrame. It helps to get a quick random view of the dataset.

# %%
df.sample(5)
# Out:
#            Product Category  \
# 65656             Men Shoes
# 35405           Men Clothes
# 74410  Mobile & Accessories
# 77059  Mobile & Accessories
# 33302           Men Clothes
#
#                                      Product Description  Price(Dollar)  \
# 65656               Etnies Men's Windrow Vulc Skate Shoe             32
# 35405                    PUMA Men's Summer Graphic Tee 1             12
# 74410  Link Depot MUSB-6 6' USB 2.0 A Male to Micro-U...              5
# 77059  PopSockets Phone Grip with Expanding Kickstand...             24
# 33302  Vertx Cutback Mens Tactical Shorts 11 inches, ...             62
#
#        Number of  reviews             Shipment Order Date
# 65656                 922  Ships to Bangladesh 2021-03-21
# 35405                  39  Ships to Bangladesh 2021-05-20
# 74410                  22  Ships to Bangladesh 2020-08-28
# 77059                   7  Ships to Bangladesh 2021-09-12
# 33302                   2  Ships to Bangladesh 2020-06-19

# %% [markdown]
# ## Complete Data Summary
#
# `print(df.describe(include='all'))` displays a complete statistical summary of all columns, including numerical and categorical data.

# %%
print(df.describe(include='all'))
# Out:
#        Product Category                                Product Description  \
# count             89082                                              89082
# unique                8                                              67942
# top           Men Shoes  KODAK Step Slim Instant Mobile Color Photo Pri...
# freq              23228                                                429
# mean                NaN                                                NaN
# min                 NaN                                                NaN
# 25%                 NaN                                                NaN
# 50%                 NaN                                                NaN
# 75%                 NaN                                                NaN
# max                 NaN                                                NaN
# std                 NaN                                                NaN
#
#         Price(Dollar)  Number of  reviews             Shipment  \
# ...

# %% [markdown]
# ## Matplotlib
#
# Matplotlib is a popular Python library used for creating data visualizations such as line charts, bar charts, scatter plots, histograms, and pie charts. It helps users analyze and present data effectively. The `pyplot` module provides a simple interface for creating graphs and customizing plots.

# %% [markdown]
# ## Install Matplotlib
#
# `!pip install matplotlib` installs the **Matplotlib** library, which is used for creating charts, graphs, and data visualizations in Python.

# %%
# !pip install matplotlib

# %% [markdown]
# ## Import Matplotlib
#
# `import matplotlib.pyplot as plt` imports the **Pyplot** module from the Matplotlib library. It is used to create charts, graphs, and visualizations in Python.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Product Category Bar Chart
#
# This code creates a bar chart showing the frequency of each product category. It helps visualize the distribution of products across different categories.

# %%
df['Product Category'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# ## Product Description Bar Chart
#
# This code creates a bar chart showing the frequency of each product description. It helps visualize the distribution of product descriptions in the dataset.

# %%
df['Price(Dollar)'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Price(Dollar)'>

# %% [markdown]
# ## Order Date Bar Chart
#
# This code creates a bar chart showing the frequency of orders for each order date. It helps visualize the distribution of orders over time.

# %%
df['Order Date'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Order Date'>

# %% [markdown]
# ## Number of Reviews Bar Chart
#
# This code creates a bar chart showing the frequency of each review count. It helps visualize the distribution of customer reviews in the dataset.

# %%
df['Number of  reviews'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Number of  reviews'>

# %% [markdown]
# ## Display Column Names
#
# `print(df.columns)` displays the names of all columns in the DataFrame. It helps verify column names before performing data analysis.

# %%
print(df.columns)
# Out:
# Index(['Product Category', 'Product Description', 'Price(Dollar)',
#        'Number of  reviews', 'Shipment', 'Order Date'],
#       dtype='str')

# %% [markdown]
# ## Select Columns
#
# This code selects the **Product Category** and **Product Description** columns from the DataFrame and stores them in the variables `x` and `y`.

# %%
x = df['Product Category']
y = df['Product Description']

# %% [markdown]
# ## Display Selected Data
#
# `print(x, y)` displays the values stored in the `x` and `y` variables. It helps verify the selected columns

# %%
print(x,y)
# Out:
# 0        Audio Video
# 1        Audio Video
# 2        Audio Video
# 3        Audio Video
# 4        Audio Video
#              ...
# 89077            Toys
# 89078            Toys
# 89079            Toys
# 89080            Toys
# 89081            Toys
# Name: Product Category, Length: 89082, dtype: str 0        Upgraded, Anker Soundcore Bluetooth Speaker wi...
# 1        Twelve South AirFly Pro Bluetooth Wireless Aud...
# 2        iOttie Easy One Touch 5 Dashboard & Windshield...
# 3        INIU Wireless Charger, 15W Fast Wireless Charg...
# 4        JBL Flip 4 Waterproof Portable Bluetooth Speak...
#                                ...
# 89077    Papo - Hand-Painted - Figurine - Marine Life -...
# 89078                         Green Toys Farm Playset. CB2
# 89079    Teenage Mutant Ninja Turtles 5" Sewer Shredder...
# 89080    Schleich Wild Life, Wild Animal Toys for Kids,...
# 89081    Schleich bayala, 5-Piece Starter Set with Fair...
# ...

# %% [markdown]
# ## Product Category Bar Chart
#
# This code creates a bar chart to display the frequency of each product category. It helps visualize how products are distributed across different categories.

# %%
import matplotlib.pyplot as plt

df['Product Category'].value_counts().plot(kind='bar')

plt.xlabel("Product Category")
plt.ylabel("Count")
plt.title("Product Category Distribution")
plt.show()

# %% [markdown]
# ## Null vs Not Null Pie Chart
#
# This code creates a pie chart showing the proportion of null and non-null values in the dataset. It helps visualize the overall data completeness.

# %%
import matplotlib.pyplot as plt

null = df.isnull().sum().sum()
not_null = df.size - null

plt.pie(
    [null, not_null],
    labels=["Null", "Not Null"],
    autopct="%1.1f%%"
)
plt.title("Null vs Not Null Values")
plt.show()

# %% [markdown]
# ## Box Plot of Price
#
# This code creates a **box plot** for the **Price(Dollar)** column. It helps identify the distribution of prices, median, spread, and potential outliers in the dataset.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
plt.boxplot(df['Price(Dollar)'].dropna())

plt.title("Box Plot of Price")
plt.ylabel("Price (Dollar)")
plt.show()

# %% [markdown]
# ## Correlation Matrix
#
# This code calculates the correlation between all numeric columns in the dataset. It helps identify the strength and direction of relationships between variables.

# %%
corr = df.corr(numeric_only=True)

# %% [markdown]
# ## Install Seaborn
#
# `!pip install seaborn` installs the **Seaborn** library, which is used for creating attractive statistical charts and data visualizations in Python.

# %%
# !pip install seaborn

# %% [markdown]
# ## Import Seaborn
#
# `import seaborn as sns` imports the Seaborn library with the alias `sns`. It is used for creating advanced statistical graphs and data visualizations in Python.

# %%
import seaborn as sns

# %% [markdown]
# ## Check Seaborn Version
#
# `print(sns.__version__)` displays the installed version of the Seaborn library. It helps verify that Seaborn is properly installed and available for use.

# %%
print(sns.__version__)
# Out:
# 0.13.2

# %% [markdown]
# +## Correlation Heatmap
#
# This code creates a correlation heatmap using Matplotlib. It shows the relationship between numeric variables and helps identify positive and negative correlations in the dataset.

# %%
import matplotlib.pyplot as plt

corr = df.corr(numeric_only=True)

plt.figure(figsize=(6,5))
plt.imshow(corr, cmap='coolwarm', interpolation='nearest')

plt.colorbar()

plt.xticks(range(len(corr.columns)), corr.columns, rotation=45)
plt.yticks(range(len(corr.columns)), corr.columns)

plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## Seaborn Correlation Heatmap
#
# This code creates a correlation heatmap using the Seaborn library. It shows the correlation between numeric variables with values displayed inside each cell, helping to understand relationships between features.

# %%
plt.figure(figsize=(6,5))
sns.heatmap(df.corr(numeric_only=True),
            annot=True,
            cmap='coolwarm')

plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## Check Seaborn Version
#
# `print(sns.__version__)` displays the current installed version of the Seaborn library. It confirms that Seaborn is successfully installed and ready to use.

# %%
print(sns.__version__)
# Out:
# 0.13.2

# %% [markdown]
# ## Correlation Heatmap using Seaborn
#
# This code creates a correlation heatmap using Seaborn. It visualizes the relationship between numeric variables and displays correlation values inside each cell for better understanding.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))

sns.heatmap(
    df.corr(numeric_only=True),
    annot=True,
    cmap='coolwarm'
)

plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## Price Histogram
#
# This code creates a histogram of the **Price(Dollar)** column. It shows the distribution of product prices by grouping them into intervals, making it easier to understand the frequency of different price ranges.

# %%
plt.figure(figsize=(8,5))

plt.hist(df["Price(Dollar)"].dropna(), bins=20)

plt.title("Histogram of Price")
plt.xlabel("Price(Dollar)")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# ## Shipment Count Plot
#
# This code creates a count plot of the **Shipment** column using Seaborn. It displays the number of records for each shipment category, helping analyze the distribution of shipment types.

# %%
plt.figure(figsize=(8,5))

sns.countplot(x="Shipment", data=df)

plt.title("Shipment Count")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ## Product Category Count Plot
#
# This code creates a horizontal count plot of the **Product Category** column using Seaborn. It shows the number of products in each category, making it easy to compare category frequencies.

# %%
plt.figure(figsize=(10,5))

sns.countplot(y="Product Category", data=df)

plt.title("Product Category Count")

plt.show()

# %% [markdown]
# ## Price Over Time Line Chart
#
# This code creates a line chart showing the relationship between **Order Date** and **Price(Dollar)**. It helps visualize how product prices change over time.

# %%
plt.figure(figsize=(10,5))

sns.lineplot(
    x="Order Date",
    y="Price(Dollar)",
    data=df
)

plt.xticks(rotation=45)

plt.title("Price Over Time")

plt.show()

# %% [markdown]
# ## Convert Order Date
#
# This code converts the **Order Date** column into a datetime format. It enables accurate date-based analysis and visualization.

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])

# %% [markdown]
# ## Check Data Type
#
# `print(df["Order Date"].dtype)` displays the data type of the **Order Date** column. It helps verify whether the column has been successfully converted to datetime format.

# %%
print(df["Order Date"].dtype)
# Out:
# datetime64[us]

# %% [markdown]
# ## Scatter Plot of Price vs Reviews
#
# This code creates a scatter plot showing the relationship between **Price(Dollar)** and **Number of Reviews**. It helps identify patterns, trends, and possible correlations between product price and customer reviews.

# %%
plt.figure(figsize=(7,5))

sns.scatterplot(
    x='Price(Dollar)',
    y='Number of  reviews',
    data=df
)

plt.title("Order Date")
plt.show()

plt.title("Order Date")

plt.show()

# %% [markdown]
# ## Pair Plot
#
# This code creates a pair plot for all numeric columns in the dataset. It helps visualize relationships, distributions, and correlations between numerical variables.

# %%
sns.pairplot(df.select_dtypes(include="number"))

plt.show()

# %% [markdown]
# ## Violin Plot of Price
#
# This code creates a violin plot for the **Price(Dollar)** column using Seaborn. It shows the distribution, density, and spread of product prices, helping identify variations and potential outliers.

# %%
plt.figure(figsize=(6,5))

sns.violinplot(y=df["Price(Dollar)"])

plt.title("Violin Plot of Price")

plt.show()

# %% [markdown]
# ## Shipment vs Price Violin Plot
#
# This code creates a violin plot showing the distribution of **Price(Dollar)** for each **Shipment** category. It helps compare price distributions, density, and variations across different shipment types.

# %%
plt.figure(figsize=(8,5))

sns.violinplot(
    x="Shipment",
    y="Price(Dollar)",
    data=df
)

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ## KDE Plot of Price
#
# This code creates a **Kernel Density Estimation (KDE)** plot for the **Price(Dollar)** column. It shows the smooth distribution of product prices and helps identify the overall data pattern and density.

# %%
plt.figure(figsize=(8,5))

sns.kdeplot(
    df["Price(Dollar)"].dropna(),
    fill=True
)

plt.title("KDE Plot of Price")

plt.show()

# %% [markdown]
# ## KDE Plot of Reviews
#
# This code creates a **Kernel Density Estimation (KDE)** plot for the **Number of Reviews** column. It shows the smooth distribution and density of customer reviews, helping identify the overall data pattern.

# %%
plt.figure(figsize=(8,5))

sns.kdeplot(
    df["Number of  reviews"].dropna(),
    fill=True
)

plt.title("KDE Plot of Reviews")

plt.show()
